# %% [markdown]
# <a href="https://colab.research.google.com/github/smish003/MSAI-631-Artificial-Intelligence-for-Human-Computer-Interaction/blob/main/SampleCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Code execution and saving the File in the GitHub Repository**
#
# *Write a python code to access the first and last item from the List*

# %%
# Intializing the List 'a' with values.
a = [5,10,15,20,25]

# %%
# Printing First element from List 'a'
print(a[0])
# Out:
# 5

# %%
# Printing Last element from List 'a'
print(a[4])
# Out:
# 25
